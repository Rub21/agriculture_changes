# %%
import pystac_client
import planetary_computer
import contextily
import geopandas

# %%
catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)

# %%
#Corredor de Conectividad Forestal Tuxtla
time_range = "2020-12-01/2020-12-31"
bbox = [-93.94014626199998,16.62133275800005,-92.94152895399998,17.22537810600005]

# search = catalog.search(collections=["sentinel-2-l2a"], bbox=bbox, datetime=time_range)
# items = search.get_all_items()
# len(items)
search = catalog.search(
    collections=["sentinel-2-l2a"],
    bbox=bbox,
    datetime=time_range,
    query={"eo:cloud_cover": {"lt": 10}},
)
items = search.get_all_items()
len(items)
# Out:
# 16

# %%
df = geopandas.GeoDataFrame.from_features(items.to_dict(), crs="epsg:4326")
ax = df[["geometry", "datetime", "s2:mgrs_tile", "eo:cloud_cover"]].plot(
    facecolor="none", figsize=(12, 6)
)
contextily.add_basemap(ax, crs=df.crs.to_string());

# %%
df = geopandas.GeoDataFrame.from_features(items.to_dict(), crs="epsg:4326")
selected_item = min(items, key=lambda item: item.properties["eo:cloud_cover"])
# selected_item = items[0]
selected_item
# Out:
# <Item id=S2A_MSIL2A_20201231T164711_R126_T15QUV_20210101T073909>

# %%
import rich.table
table = rich.table.Table("Asset Key", "Description")
for asset_key, asset in selected_item.assets.items():
    table.add_row(asset_key, asset.title)
table
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Asset Key          ┃ Description                           ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ AOT                │ Aerosol optical thickness (AOT)       │
# │ B01                │ Band 1 - Coastal aerosol - 60m        │
# │ B02                │ Band 2 - Blue - 10m                   │
# │ B03                │ Band 3 - Green - 10m                  │
# │ B04                │ Band 4 - Red - 10m                    │
# │ B05                │ Band 5 - Vegetation red edge 1 - 20m  │
# │ B06                │ Band 6 - Vegetation red edge 2 - 20m  │
# │ B07                │ Band 7 - Vegetation red edge 3 - 20m  │
# │ B08                │ Band 8 - NIR - 10m                    │
# │ B09                │ Band 9 - Water vapor - 60m            │
# │ B11                │ Band 11 - SWIR (1.6) - 20m            │
# │ B12                │ Band 12 - SWIR (2.2) - 20m            │
# │ B8A                │ Band 8A - Vegetation red edge 4 - 20m │
# │ SCL                │ Scene classfication map (SCL)         │
# │ WVP                │ Water vapour (WVP)                    │
# │ visual             │ True color image                      │
# │ preview            │ Thumbnail                             │
# │ safe-manifest      │ SAFE manifest                         │
# │ granule-metadata   │ Granule metadata                      │
# │ inspire-metadata   │ INSPIRE metadata                      │
# │ product-metadata   │ Product metadata                      │
# │ datastrip-metadata │ Datastrip metadata                    │
# │ tilejson           │ TileJSON with default rendering       │
# │ rendered_preview   │ Rendered preview                      │
# └────────────────────┴───────────────────────────────────────┘

# %%
selected_item.assets["rendered_preview"].to_dict()
# Out:
# {'href': 'https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=sentinel-2-l2a&item=S2A_MSIL2A_20201231T164711_R126_T15QUV_20210101T073909&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png',
#  'type': 'image/png',
#  'title': 'Rendered preview',
#  'rel': 'preview',
#  'roles': ['overview']}

# %% [markdown]
# # Show RGB preview

# %%
from IPython.display import Image
Image(url=selected_item.assets["rendered_preview"].href, width=200)
# Out:
# <img src="https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=sentinel-2-l2a&item=S2A_MSIL2A_20201231T164711_R126_T15QUV_20210101T073909&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png" width="200"/>

# %%
def display_multiple_img(images, rows = 1, cols=1, size=20,cmap='gist_earth'):
    figure, ax = plt.subplots(nrows=rows,ncols=cols,figsize=(size, size) )
    for ind,title in enumerate(images):
        ax.ravel()[ind].imshow(images[title].variable.data[0],cmap = cmap)
        ax.ravel()[ind].set_title(title)
        ax.ravel()[ind].set_axis_off()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Display all bands

# %%
import rioxarray
from rioxarray.merge import merge_arrays
import numpy as np

def read_bands(bands):
  vv_objs={}
  for band in bands:
    href = selected_item.assets[band].href
    ds = rioxarray.open_rasterio(href)
    print(f"{band}, {ds.shape}")
    vv_objs[band]=ds
  # arr_st = np.stack(vv_list)
  return vv_objs

# %%
bands_10m=["B02","B03", "B04","B08"]
print(bands_10m)
# bands_20m=["B05","B06", "B07","B11","B12", "B8A"]
# bands_60m=["B01","B09"]
vv_objs_10m = read_bands(bands_10m)
# display_multiple_img(vv_objs_10m,2,2,10)
# Out:
# ['B02', 'B03', 'B04', 'B08']
# B02, (1, 10980, 10980)
# B03, (1, 10980, 10980)
# B04, (1, 10980, 10980)
# B08, (1, 10980, 10980)

# %%
b02=vv_objs_10m["B02"]
b03 = vv_objs_10m["B03"]
b04 = vv_objs_10m["B04"]
b04
# print(b02.attrs)

# imgxyb = np.empty(( b02.rio.height,  b02.rio.width,  b02.rio.count),  b02.rio.attrs)


# for index, band in enumerate(bands_10m):
#     # print(index, band)
#     imgxyb[:,:,index] = vv_objs_10m[band].variable.data[0]
# Out:
# <xarray.DataArray (band: 1, y: 10980, x: 10980)>
# array([[[205, 201, ..., 152, 183],
#         [266, 243, ..., 183, 205],
#         ...,
#         [273, 574, ..., 173, 168],
#         [249, 292, ..., 193, 202]]], dtype=uint16)
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 3e+05 3e+05 3e+05 ... 4.098e+05 4.098e+05 4.098e+05
#   * y            (y) float64 2e+06 2e+06 2e+06 ... 1.89e+06 1.89e+06 1.89e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
